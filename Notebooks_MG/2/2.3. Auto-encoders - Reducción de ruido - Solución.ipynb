# %% [markdown]
# <div><img style="float: right; width: 80px; vertical-align:middle" src="https://www.upm.es/sfs/Rectorado/Gabinete%20del%20Rector/Logos/EU_Informatica/ETSI%20SIST_INFORM_COLOR.png" alt="ETSISI logo" />
#
#
# # Reducción de ruido con autoencoders<a id="top"></a>
#
# <i><small>Authors: Félix José Fuentes Hurtado<br>Last update: 2023-09-29</small></i></div>
#
# ***

# %% [markdown]
# ### Reducción de ruido con autoencoders
#
# En este notebook vamos a ver cómo podemos implementar un autoencoder convolucional y utilizarlo para reducir el ruido presente en los datos de entrada. Todos los ejemplos están extraídos del propio blog de Keras, aquí tenéis el [enlace](https://blog.keras.io/building-autoencoders-in-keras.html) para su consulta.
#
# Comenzemos recordando qué es un autoencoder convolucional. Para ello, mirad la imagen siguiente:

# %% [markdown]
# ![ae.png](data:image/png;base64,...)

# %% [markdown]
# En ella podemos observar como consta de dos bloques: el encoder y el decoder.
#
# Por una parte, el **encoder** toma los datos de entrada y los comprime en una representación mucho más compacta.
#
# Por la otra, el **decoder** coge esa representación (o codificación) comprimida y trata de reconstruir los datos originales con el menor error posible.

# %% [markdown]
# A lo largo de esta práctica implementaremos un autoencoder convolucional y lo emplearemos para reducir el ruido de los datos de entrada.
#
# Para ello, primero implementaremos la arquitectura y la probaremos con la tarea de reconstruir los datos simplemente.
#
# Después, añadiremos ruido a las imágenes y reentrenaremos el autoencoder para que lo elimine y produzca la versión limpia de las mismas.

# %% [markdown]
# **¡Comenzemos!**

# %% [markdown]
# Vamos a implementar nuestro primer autoencoder convolucional. La arquitectura del autoencoder será la siguiente:
#
# Para el encoder:
#
# - Capa Convolucional, 16 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
# - Capa Convolucional, 8 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
# - Capa Convolucional, 4 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
#
# Para el decoder:
#
# - Capa Convolucional, 4 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 8 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 16 filtros de 3x3, activación `ReLU` y padding `valid`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 1 filtros de 3x3, activación `sigmoid` y padding `same`
#
#
# **Pregunta**: ¿Qué tamaño tendrá el bottleneck?
#
# **Respuesta**: Yendo de capa en capa desde la entrada: (28, 28, 1) --> (28, 28, 16) --> (14, 14, 16) --> (14, 14, 8) --> (7, 7, 4) --> (4, 4, 4)
#
# En el último paso, al hacer el último pooling, pasaremos de 7x7 a 4x4, ya que irá obteniendo el máximo de cada región 2x2. Como la entrada tiene 7x7, en el último paso no tendrá 2x2 sino 2x1.

# %%
import keras
from keras import layers

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 4) i.e. 64-dimensional

x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# Ahora obtendremos las imágenes y las normalizaremos entre 0 y 1: dividiremos entre 255, ya que las imágenes están codificadas con 8 bits sin signo (uint8).

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255

# %% [markdown]
# Como vamos a trabajar con imágenes, tenemos que redimensionar los datos para que tengan 2 dimensiones: de 786 a (28, 28, 1), porque son imágenes en escala de grises.

# %%
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %% [markdown]
# Tras esto, entrenamos nuestro DC (Deep Convolutional) AutoEncoder:
#
# *(Atención: ahora es importante tener seleccionada GPU o TPU, de lo contrario el entrenaiento será muy lento)*

# %%
logs = autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 469/469 [==============================] - 20s 16ms/step - loss: 0.2305 - val_loss: 0.1646
# Epoch 2/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1516 - val_loss: 0.1402
# Epoch 3/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1367 - val_loss: 0.1315
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1302 - val_loss: 0.1268
# Epoch 5/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1259 - val_loss: 0.1231
# Epoch 6/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1228 - val_loss: 0.1209
# Epoch 7/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1207 - val_loss: 0.1188
# Epoch 8/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1189 - val_loss: 0.1168
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1174 - val_loss: 0.1156
# Epoch 10/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1160 - val_loss: 0.1140
# Epoch 11/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1147 - val_loss: 0.1128
# Epoch 12/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1136 - val_loss: 0.1119
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1126 - val_loss: 0.1116
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1117 - val_loss: 0.1101
# Epoch 15/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1109 - val_loss: 0.1094
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1102 - val_loss: 0.1087
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1097 - val_loss: 0.1089
# Epoch 18/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1091 - val_loss: 0.1075
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1088 - val_loss: 0.1071
# Epoch 20/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1082 - val_loss: 0.1069
# Epoch 21/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1078 - val_loss: 0.1065
# Epoch 22/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1075 - val_loss: 0.1059
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1071 - val_loss: 0.1056
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1068 - val_loss: 0.1054
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1065 - val_loss: 0.1057
# Epoch 26/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1062 - val_loss: 0.1049
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1059 - val_loss: 0.1050
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1057 - val_loss: 0.1046
# Epoch 29/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1054 - val_loss: 0.1043
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1052 - val_loss: 0.1040
# Epoch 31/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1049 - val_loss: 0.1039
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1047 - val_loss: 0.1036
# Epoch 33/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1045 - val_loss: 0.1036
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1043 - val_loss: 0.1030
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1041 - val_loss: 0.1028
# Epoch 36/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1039 - val_loss: 0.1028
# Epoch 37/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1037 - val_loss: 0.1026
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1036 - val_loss: 0.1028
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1033 - val_loss: 0.1023
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1031 - val_loss: 0.1025
# Epoch 41/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1030 - val_loss: 0.1017
# Epoch 42/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1028 - val_loss: 0.1018
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1026 - val_loss: 0.1022
# Epoch 44/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1024 - val_loss: 0.1011
# Epoch 45/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1022 - val_loss: 0.1012
# Epoch 46/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1021 - val_loss: 0.1008
# Epoch 47/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1019 - val_loss: 0.1009
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1018 - val_loss: 0.1006
# Epoch 49/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.1016 - val_loss: 0.1005
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1015 - val_loss: 0.1003

# %% [markdown]
# También podemos visualizar las curvas de entrenamiento, que se guardan en la variable history:

# %%
logs.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(logs.history['loss'])
plt.plot(logs.history['val_loss'])

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Ya hemos conseguido entrenar nuestro autoencoder para que reconstruya los datos de entrada.
#
# Ahora probaremos a añadirle ruido a las imágenes y lo entrenaremos para que lo elimine. De esta forma, la entrada serán imágenes ruidosas y la salida imágenes limpias. O eso deseamos.

# %% [markdown]
# Vamos a generar ruido sintético en nuestras imágenes y a tratar de eliminarlo con nuestro modelo.

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# add noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# Veamos qué es lo que hemos hecho. Vamos a visualizar las imágenes originales y después las "ruidosas":

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_train[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_train_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# En efecto, hemos añadido una cantidad de ruido considerable. Vamos a intentar eliminarlo con un el autoencoder convolucional que hemos implementado anteriormente:

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 4) i.e. 64-dimensional

x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

logs = autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/50
# 469/469 [==============================] - 8s 8ms/step - loss: 0.2932 - val_loss: 0.2214
# Epoch 2/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2099 - val_loss: 0.1987
# Epoch 3/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1892 - val_loss: 0.1793
# Epoch 4/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1759 - val_loss: 0.1715
# Epoch 5/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1695 - val_loss: 0.1654
# Epoch 6/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1649 - val_loss: 0.1616
# Epoch 7/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1615 - val_loss: 0.1590
# Epoch 8/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1590 - val_loss: 0.1564
# Epoch 9/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1568 - val_loss: 0.1545
# Epoch 10/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1549 - val_loss: 0.1531
# Epoch 11/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1536 - val_loss: 0.1515
# Epoch 12/50
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1522 - val_loss: 0.1501
# Epoch 13/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1511 - val_loss: 0.1492
# Epoch 14/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1499 - val_loss: 0.1479
# Epoch 15/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1488 - val_loss: 0.1466
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1478 - val_loss: 0.1461
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1470 - val_loss: 0.1448
# Epoch 18/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1462 - val_loss: 0.1448
# Epoch 19/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1456 - val_loss: 0.1439
# Epoch 20/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1450 - val_loss: 0.1433
# Epoch 21/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1445 - val_loss: 0.1427
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1440 - val_loss: 0.1419
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1435 - val_loss: 0.1420
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1432 - val_loss: 0.1413
# Epoch 25/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1428 - val_loss: 0.1415
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1425 - val_loss: 0.1412
# Epoch 27/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1423 - val_loss: 0.1404
# Epoch 28/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1419 - val_loss: 0.1400
# Epoch 29/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1416 - val_loss: 0.1400
# Epoch 30/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1414 - val_loss: 0.1401
# Epoch 31/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1411 - val_loss: 0.1413
# Epoch 32/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1411 - val_loss: 0.1393
# Epoch 33/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1407 - val_loss: 0.1388
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1405 - val_loss: 0.1392
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1404 - val_loss: 0.1386
# Epoch 36/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1402 - val_loss: 0.1384
# Epoch 37/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1400 - val_loss: 0.1382
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1399 - val_loss: 0.1397
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1397 - val_loss: 0.1379
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1396 - val_loss: 0.1378
# Epoch 41/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1394 - val_loss: 0.1376
# Epoch 42/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1393 - val_loss: 0.1376
# Epoch 43/50
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1391 - val_loss: 0.1373
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1390 - val_loss: 0.1373
# Epoch 45/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1389 - val_loss: 0.1371
# Epoch 46/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1389 - val_loss: 0.1376
# Epoch 47/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1386 - val_loss: 0.1379
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1386 - val_loss: 0.1366
# Epoch 49/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1384 - val_loss: 0.1368
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1383 - val_loss: 0.1365

# %%
plt.plot(logs.history['loss'])
plt.plot(logs.history['val_loss'])

# %% [markdown]
# Visualicemos ahora los resultados, a ver qué hemos conseguido:

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ¿Qué os parece? Nada mal, ¿no? ¡Hemos conseguido eliminar totalmente el ruido!

# %% [markdown]
# ### Pregunta: ¿Cuánto créeis que podéis simplificar la arquitectura y que todavía funcione?
#
# Probad con la siguiente arquitectura:
#
#
# Para el encoder:
#
# - Capa Convolucional, 4 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
# - Capa Convolucional, 2 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
# - Capa Convolucional, 1 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa MaxPooling2D, tamaño de pooling 2x2, padding `same`
#
# Para el decoder:
#
# - Capa Convolucional, 1 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 2 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 4 filtros de 3x3, activación `ReLU` y padding `same`
# - Capa UpSampling2D, factor de upsample 2x2
# - Capa Convolucional, 1 filtros de 3x3, activación `sigmoid` y padding `same`
#
#
# **Pregunta**: ¿Qué tamaño tendrá el bottleneck?
#
# **Respuesta**: Yendo de capa en capa desde la entrada: (28, 28, 1) --> (28, 28, 4) --> (14, 14, 4) --> (14, 14, 2) --> (7, 7, 2) --> (4, 4, 1)

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(2, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(1, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (4, 4, 1)

x = layers.Conv2D(1, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(2, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(4, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)


autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

logs = autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/50
# 469/469 [==============================] - 6s 7ms/step - loss: 0.3584 - val_loss: 0.2642
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2431 - val_loss: 0.2337
# Epoch 3/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2296 - val_loss: 0.2269
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2232 - val_loss: 0.2207
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2192 - val_loss: 0.2174
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2162 - val_loss: 0.2148
# Epoch 7/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2141 - val_loss: 0.2133
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2129 - val_loss: 0.2122
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2120 - val_loss: 0.2113
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2112 - val_loss: 0.2106
# Epoch 11/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2106 - val_loss: 0.2101
# Epoch 12/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2101 - val_loss: 0.2095
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2095 - val_loss: 0.2090
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2087 - val_loss: 0.2081
# Epoch 15/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2080 - val_loss: 0.2073
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2073 - val_loss: 0.2066
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2068 - val_loss: 0.2061
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2062 - val_loss: 0.2055
# Epoch 19/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2059 - val_loss: 0.2051
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2055 - val_loss: 0.2049
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2052 - val_loss: 0.2047
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2050 - val_loss: 0.2043
# Epoch 23/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2048 - val_loss: 0.2042
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2047 - val_loss: 0.2041
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2046 - val_loss: 0.2039
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2044 - val_loss: 0.2039
# Epoch 27/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2044 - val_loss: 0.2039
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2043 - val_loss: 0.2036
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2042 - val_loss: 0.2036
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2041 - val_loss: 0.2035
# Epoch 31/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2041 - val_loss: 0.2034
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2041 - val_loss: 0.2034
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2040 - val_loss: 0.2036
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2040 - val_loss: 0.2033
# Epoch 35/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2039 - val_loss: 0.2032
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2039 - val_loss: 0.2033
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2039 - val_loss: 0.2032
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2039 - val_loss: 0.2032
# Epoch 39/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2038 - val_loss: 0.2032
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2038 - val_loss: 0.2031
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2038 - val_loss: 0.2032
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2038 - val_loss: 0.2030
# Epoch 43/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2038 - val_loss: 0.2030
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2038 - val_loss: 0.2030
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2037 - val_loss: 0.2030
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2037 - val_loss: 0.2030
# Epoch 47/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2037 - val_loss: 0.2031
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2037 - val_loss: 0.2032
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2037 - val_loss: 0.2031
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2037 - val_loss: 0.2029

# %%
plt.plot(logs.history['loss'])
plt.plot(logs.history['val_loss'])

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Parece que con un bottleneck con un código latente de 16 elementos (`4x4x1`) no es suficiente.
#
# ### Ejercicio
#
# **Modifíca la arquitectura hasta conseguir el mínimo código latente que consiga eliminar el ruido de las imágenes de forma satisfactoria.**
#
# *TIP*: Puedes probar con espacios latentes de `32 elementos (4, 4, 2)`, `48 elementos (4, 4, 3)` y `64 elementos (4, 4, 4)`. Recuerda que la estructura del encoder-decoder es tal que el encoder reduce las dimensiones y el decoder las aumenta.

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(3, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (4, 4, 3)

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(6, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)


autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

logs = autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))


plt.plot(logs.history['loss'])
plt.plot(logs.history['val_loss'])

decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 6s 8ms/step - loss: 0.3007 - val_loss: 0.2416
# Epoch 2/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2123 - val_loss: 0.1983
# Epoch 3/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1924 - val_loss: 0.1873
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1846 - val_loss: 0.1800
# Epoch 5/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1780 - val_loss: 0.1743
# Epoch 6/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1729 - val_loss: 0.1699
# Epoch 7/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1691 - val_loss: 0.1665
# Epoch 8/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1663 - val_loss: 0.1643
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1643 - val_loss: 0.1627
# Epoch 10/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1628 - val_loss: 0.1612
# Epoch 11/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1617 - val_loss: 0.1601
# Epoch 12/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1608 - val_loss: 0.1593
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1597 - val_loss: 0.1576
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1584 - val_loss: 0.1566
# Epoch 15/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1574 - val_loss: 0.1557
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1566 - val_loss: 0.1552
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1559 - val_loss: 0.1545
# Epoch 18/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1553 - val_loss: 0.1537
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1547 - val_loss: 0.1532
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1542 - val_loss: 0.1529
# Epoch 21/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1539 - val_loss: 0.1523
# Epoch 22/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1534 - val_loss: 0.1524
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1531 - val_loss: 0.1518
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1527 - val_loss: 0.1516
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1524 - val_loss: 0.1512
# Epoch 26/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1521 - val_loss: 0.1509
# Epoch 27/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1518 - val_loss: 0.1505
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1516 - val_loss: 0.1502
# Epoch 29/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1513 - val_loss: 0.1499
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1511 - val_loss: 0.1496
# Epoch 31/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1508 - val_loss: 0.1493
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1506 - val_loss: 0.1491
# Epoch 33/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1503 - val_loss: 0.1489
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1503 - val_loss: 0.1489
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1500 - val_loss: 0.1489
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1498 - val_loss: 0.1484
# Epoch 37/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1495 - val_loss: 0.1482
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1494 - val_loss: 0.1480
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1493 - val_loss: 0.1485
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1491 - val_loss: 0.1485
# Epoch 41/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1490 - val_loss: 0.1477
# Epoch 42/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1488 - val_loss: 0.1478
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1487 - val_loss: 0.1473
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1486 - val_loss: 0.1473
# Epoch 45/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1485 - val_loss: 0.1473
# Epoch 46/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1484 - val_loss: 0.1471
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1483 - val_loss: 0.1469
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1483 - val_loss: 0.1467
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1481 - val_loss: 0.1469
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1480 - val_loss: 0.1468
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Podemos observar que un tamaño de 48 elementos para el espacio latente o *bottleneck* (`4x4x3`) empieza a ser suficiente para este sencillo problema.
#
# El tamaño y complejidad del autoencoder dependerá, principalmente, de la dificultad del problema y de los datos.
