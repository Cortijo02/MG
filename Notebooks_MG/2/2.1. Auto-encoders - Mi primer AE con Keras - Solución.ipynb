# %% [markdown]
# <div><img style="float: right; width: 80px; vertical-align:middle" src="https://www.upm.es/sfs/Rectorado/Gabinete%20del%20Rector/Logos/EU_Informatica/ETSI%20SIST_INFORM_COLOR.png" alt="ETSISI logo" />
#
#
# # Mi primer AE con Keras<a id="top"></a>
#
# <i><small>Authors: Félix José Fuentes Hurtado<br>Last update: 2023-09-29</small></i></div>
#
# ***

# %% [markdown]
# ### Mi primer AutoEncoder con Keras
#
# En este notebook vamos a ver cómo podemos implementar un autoencoder paso a paso. Todos los ejemplos están extraídos del propio blog de Keras, aquí tenéis el [enlace](https://blog.keras.io/building-autoencoders-in-keras.html) para su consulta.
#
# Comenzemos recordando qué es un autoencoder. Para ello, mirad la imagen siguiente:

# %% [markdown]
# ![autoencoder_schema.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# En ella podemos observar como consta de dos bloques: el encoder y el decoder.
#
# Por una parte, el **encoder** toma los datos de entrada y los comprime en una representación mucho más compacta.
#
# Por la otra, el **decoder** coge esa representación (o codificación) comprimida y trata de reconstruir los datos originales con el menor error posible.

# %% [markdown]
# A lo largo de esta práctica haremos lo siguiente:
#
# * Empezaremos con un AutoEncoder muy simple, en el que tanto el encoder como el decoder tendrán una sola capa Densa.
# * Complicaremos un poco más la arquitectura añadiendo más capas

# %% [markdown]
# **¡Comenzemos!**
#
# Vamos a construir el AutoEncoder más simple posible:

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))

# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))

# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]

# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# Ahora necesitamos compilarlo con la función `compile` de Keras. Como optimizador utilizaremos `Adam` con sus valores por defecto (búscalos en la documentación de Keras) y como función de pérdidas la entropía cruzada binaria (busca cómo elegirla en la documentación de Keras).

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# Ya tenemos nuestro modelo configurado. Ahora vamos a por los datos. Vamos a trabajar con el conjunto de datos más sencillo y utilizado que existe en el Deep Learning: el MNIST.
#
# Keras nos lo ofrece directamente en su API:

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Recordad que siempre que trabajemos con redes neuronales será importante normalizar/estandarizar nuestros datos. En este caso, vamos a normalizarlos.
#
# Como son imágenes codificadas en uint8, significa que tenemos 8 bits, lo que da lugar a $2^{8-1}$ valores.
#
# De acuerdo a esto, normaliza los datos.

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# Una vez normalizado, y debido a que estamos implementando una red neuronal *densa* que toma como entrada vectores de datos, deberemos **vectorizar** los datos. Es decir, convertirlos de matriz a vector.
#
# Esto os debería dar un vector de `train` de dimensiones `(60000, 784)` y uno de `test` de `(10000, 784)`. Comprobadlo.

# %%
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)

# %% [markdown]
# Y ya lo tenemos todo listo. Ahora nos queda entrenar el modelo con la función `fit`.
#
# Los parámetros que elegiremos para este entrenamiento son 50 épocas, un tamaño de batch de 256, aleatorizaremos las muestras en cada época, y validaremos con los datos de `x_test, x_test`.
#
# **Pregunta**: ¿Por qué usamos como conjunto de validación `(x_test, x_test)` en lugar de `(x_test, y_test)` como haríamos habitualmente?
#
# **Respuesta**: Porque estamos tratando de reconstruir los datos de entrada, por lo que la salida debería ser lo más cercana posible a `x_test`.

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 4s 5ms/step - loss: 0.2760 - val_loss: 0.1904
# Epoch 2/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1705 - val_loss: 0.1530
# Epoch 3/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1442 - val_loss: 0.1335
# Epoch 4/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1285 - val_loss: 0.1213
# Epoch 5/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1184 - val_loss: 0.1131
# Epoch 6/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1114 - val_loss: 0.1074
# Epoch 7/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1062 - val_loss: 0.1028
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1023 - val_loss: 0.0995
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0994 - val_loss: 0.0971
# Epoch 10/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0974 - val_loss: 0.0954
# Epoch 11/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0961 - val_loss: 0.0944
# Epoch 12/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0952 - val_loss: 0.0937
# Epoch 13/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0947 - val_loss: 0.0932
# Epoch 14/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0943 - val_loss: 0.0929
# Epoch 15/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0940 - val_loss: 0.0927
# Epoch 16/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 17/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 18/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0936 - val_loss: 0.0923
# Epoch 19/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 20/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 21/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 22/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 23/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 24/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 25/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 27/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 28/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 29/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 30/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 33/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 35/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 36/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 37/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 38/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 39/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 40/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 41/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 42/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 43/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 45/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 46/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 47/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 48/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 49/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 50/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0927 - val_loss: 0.0916

# %% [markdown]
# Ya tenemos nuestra red entrenada. Vamos ahora a visualizar algunos casos:

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ¡Fijaos lo fácil que ha sido, ya tenemos nuestro primer autoencoder funcionando!
#
#  Lo que está ocurriendo es que el autoencoder está calculando una representación comprimida de los datos (lo que obtenemos a la salida del encoder) que no es otra cosa que una aproximación a lo que obtendríamos si aplicásemos una PCA. Si no sabéis de lo que estamos hablando, os recomiendo que veáis el video de Geoffrey Hinton "[From PCA to autoencoders](https://www.youtube.com/watch?v=PSOt7u8u23w)".

# %% [markdown]
# Vamos a complicar un poco el asunto. Vamos a convertir nuestro autoencoder en un **deep** autoencoder. ¿Cómo? Añadiendo más capas al encoder y al decoder.
#
# En este caso, vamos a crear un autoencoder con:
#
# Para el encoder:
#
# - Capa Densa, 128 neuronas y función de activación ReLU
# - Capa Densa, 64 neuronas y función de activación ReLU
# - Capa Densa, 32 neuronas y función de activación ReLU
#
# Para el decoder:
#
# - Capa Densa, 32 neuronas y función de activación ReLU
# - Capa Densa, 64 neuronas y función de activación ReLU
# - Capa Densa, 128 neuronas y función de activación Sigmoid

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %% [markdown]
# **Pregunta**: ¿Por qué creeis que en el decoder van reduciendose el número de neuronas y en el decoder aumentando?
#
# **Respuesta**: para conseguir comprimir los datos en el *bottleneck* y luego reconstruirlos a la salida.
#
# **Pregunta**: ¿Por qué utilizamos la función de activación **sigmoid** en la última capa?
#
# **Respuesta**: porque estamos utilizando una función de pérdidas de tipo entropía cruzada binaria, por lo que estará esperando valores 0 o 1, que es lo que consigue la función **sigmoid**.

# %% [markdown]
# Una vez configurado el modelo, podemos **crear el modelo** (mira la clase `keras.Model`) y compilarlo (usaremos de nuevo `Adam` y la entropía cruzada binaria.

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# Y, por último, entrenaremos el modelo. En esta ocasión lo ejecutaremos durante 100 épocas, con un tamaño de batch de 256, aleatorización de las muestras y conjunto de validación `x_test, x_test`.

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2502 - val_loss: 0.1704
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1521 - val_loss: 0.1381
# Epoch 3/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1325 - val_loss: 0.1262
# Epoch 4/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1240 - val_loss: 0.1194
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1179 - val_loss: 0.1136
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1127 - val_loss: 0.1090
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1089 - val_loss: 0.1064
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1064 - val_loss: 0.1040
# Epoch 9/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1041 - val_loss: 0.1023
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1022 - val_loss: 0.1004
# Epoch 11/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1005 - val_loss: 0.0985
# Epoch 12/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0990 - val_loss: 0.0973
# Epoch 13/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0977 - val_loss: 0.0964
# Epoch 14/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0967 - val_loss: 0.0957
# Epoch 15/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0958 - val_loss: 0.0943
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0948 - val_loss: 0.0937
# Epoch 17/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0941 - val_loss: 0.0930
# Epoch 18/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0934 - val_loss: 0.0925
# Epoch 19/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 20/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0921 - val_loss: 0.0911
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0915 - val_loss: 0.0907
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0909 - val_loss: 0.0901
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0904 - val_loss: 0.0897
# Epoch 24/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0900 - val_loss: 0.0891
# Epoch 25/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0895 - val_loss: 0.0888
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0892 - val_loss: 0.0884
# Epoch 27/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0888 - val_loss: 0.0881
# Epoch 28/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0885 - val_loss: 0.0878
# Epoch 29/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0882 - val_loss: 0.0876
# Epoch 30/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0879 - val_loss: 0.0875
# Epoch 31/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0877 - val_loss: 0.0873
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0871 - val_loss: 0.0867
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0869 - val_loss: 0.0863
# Epoch 35/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0867 - val_loss: 0.0859
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0864 - val_loss: 0.0860
# Epoch 37/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0862 - val_loss: 0.0857
# Epoch 38/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0861 - val_loss: 0.0854
# Epoch 39/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0859 - val_loss: 0.0854
# Epoch 40/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 41/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0856 - val_loss: 0.0850
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0855 - val_loss: 0.0849
# Epoch 43/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0854 - val_loss: 0.0850
# Epoch 44/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0853 - val_loss: 0.0847
# Epoch 45/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0852 - val_loss: 0.0845
# Epoch 46/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0851 - val_loss: 0.0845
# Epoch 47/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0850 - val_loss: 0.0846
# Epoch 48/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0848 - val_loss: 0.0850
# Epoch 49/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0848 - val_loss: 0.0843
# Epoch 50/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0847 - val_loss: 0.0846
# Epoch 51/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0846 - val_loss: 0.0843
# Epoch 52/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0845 - val_loss: 0.0841
# Epoch 53/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0845 - val_loss: 0.0839
# Epoch 54/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0844 - val_loss: 0.0840
# Epoch 55/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0843 - val_loss: 0.0840
# Epoch 56/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0842 - val_loss: 0.0839
# Epoch 57/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0842 - val_loss: 0.0839
# Epoch 58/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0841 - val_loss: 0.0836
# Epoch 59/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0841 - val_loss: 0.0838
# Epoch 60/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0840 - val_loss: 0.0838
# Epoch 61/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0839 - val_loss: 0.0836
# Epoch 62/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0839 - val_loss: 0.0837
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0838 - val_loss: 0.0837
# Epoch 64/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0838 - val_loss: 0.0833
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0837 - val_loss: 0.0836
# Epoch 66/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0837 - val_loss: 0.0833
# Epoch 67/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0836 - val_loss: 0.0832
# Epoch 68/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0836 - val_loss: 0.0834
# Epoch 69/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0836 - val_loss: 0.0832
# Epoch 70/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0835 - val_loss: 0.0833
# Epoch 71/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0835 - val_loss: 0.0832
# Epoch 72/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0834 - val_loss: 0.0832
# Epoch 73/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0834 - val_loss: 0.0830
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0833 - val_loss: 0.0829
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0833 - val_loss: 0.0831
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0833 - val_loss: 0.0830
# Epoch 77/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0832 - val_loss: 0.0833
# Epoch 79/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0832 - val_loss: 0.0828
# Epoch 80/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0831 - val_loss: 0.0832
# Epoch 81/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0831 - val_loss: 0.0831
# Epoch 82/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0830 - val_loss: 0.0829
# Epoch 83/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0831 - val_loss: 0.0828
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0830 - val_loss: 0.0829
# Epoch 85/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0830 - val_loss: 0.0827
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0829 - val_loss: 0.0831
# Epoch 87/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0829 - val_loss: 0.0830
# Epoch 88/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0829 - val_loss: 0.0828
# Epoch 89/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0828 - val_loss: 0.0830
# Epoch 90/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0828 - val_loss: 0.0827
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 92/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 94/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0827 - val_loss: 0.0826
# Epoch 95/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 96/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0827 - val_loss: 0.0827
# Epoch 97/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 98/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0826 - val_loss: 0.0825
# Epoch 99/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0826 - val_loss: 0.0823
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0826 - val_loss: 0.0827

# %% [markdown]
# Fijaos en cómo las pérdidas que obtenemos ahora son un poco mejores: de ~0.09 que obteníamos antes en validación, a ~0.08.

# %% [markdown]
# Vamos ahora a visualizar algunos casos:

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
decoded_imgs = autoencoder.predict(x_test)

# %%
# Use Matplotlib
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
